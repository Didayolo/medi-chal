# %%
problem_dir = 'data_manager/'  
from sys import path
path.append(problem_dir)
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from auto_ml import AutoML

input_dir = 'sample_data'
basename = 'iris'
D = AutoML(input_dir, basename)

# %%
D.info
# Out:
# {'feat_num': '4',
#  'feat_type': array(['float64', 'float64', 'float64', 'float64'], dtype=object),
#  'has_categorical': '0',
#  'has_missing': '0',
#  'is_sparse': '0',
#  'label_num': '3',
#  'metric': 'bac_metric',
#  'name': 'iris',
#  'target_num': '3',
#  'target_type': 'Numerical',
#  'task': 'multiclass.classification',
#  'test_num': '30',
#  'time_budget': '1200',
#  'train_num': '105',
#  'usage': 'Sample dataset Iris data',
#  'valid_num': '15'}

# %%
D.get_data_as_df()[0]
# Out:
#     (sepal_length,)  (sepal_width,)  (petal_length,)  (petal_width,)
# 0               4.4             3.0              1.3             0.2
# 1               4.7             3.2              1.6             0.2
# 2               6.1             2.6              5.6             1.4
# 3               6.4             3.1              5.5             1.8
# 4               5.8             4.0              1.2             0.2
# 5               5.0             3.5              1.6             0.6
# 6               5.0             2.0              3.5             1.0
# 7               4.9             3.1              1.5             0.1
# 8               6.3             2.8              5.1             1.5
# 9               5.6             2.8              4.9             2.0
# 10              4.9             2.5              4.5             1.7
# 11              6.4             2.8              5.6             2.2
# 12              6.2             2.8              4.8             1.8
# 13              5.0             3.3              1.4             0.2
# 14              7.2             3.2              6.0             1.8
# 15              6.3             2.5              5.0             1.9
# 16              5.4             3.4              1.5             0.4
# 17              6.0             3.0              4.8             1.8
# 18              5.8             2.7              4.1             1.0
# 19              5.5             2.4              3.7             1.0
# 20              4.8             3.0              1.4             0.1
# 21              4.6             3.2              1.4             0.2
# 22              6.4             3.2              5.3             2.3
# 23              6.3             2.5              4.9             1.5
# 24              6.3             2.9              5.6             1.8
# 25              4.3             3.0              1.1             0.1
# 26              5.0             3.0              1.6             0.2
# 27              6.9             3.1              5.1             2.3
# 28              5.1             3.4              1.5             0.2
# 29              7.7             2.8              6.7             2.0
# 30              4.8             3.4              1.6             0.2
# 31              4.5             2.3              1.3             0.3
# 32              5.5             3.5              1.3             0.2
# 33              4.6             3.6              1.0             0.2
# 34              7.2             3.6              6.1             2.5
