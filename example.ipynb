# %%
problem_dir = 'data_manager/'  
from sys import path
path.append(problem_dir)
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from auto_ml import AutoML

input_dir = 'sample_data'
basename = 'iris'
D = AutoML(input_dir, basename)

# %%
D.show_descriptors()
# Out:
# Scatter plot matrix
# X_train
# X_test
# Classes distribution
# y_train
# y_test
# Hierarchical clustering heatmap
# X_train
#
# Performing hiearchical clustering using euclidean for columns and euclidean for rows
# Column clustering completed in 0.2 seconds
# data_manager/utilities.py:171: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Y2 = sch.linkage(D2, method=column_method, metric=column_metric) ### array-clustering metric - 'average', 'single', 'centroid', 'complete'
# Row clustering completed in 0.2 seconds
# data_manager/utilities.py:187: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Y1 = sch.linkage(D1, method=row_method, metric=row_metric) ### gene-clustering metric - 'average', 'single', 'centroid', 'complete'
# X_test
#
# ...

# %%
D.get_processed_data()['X_train']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 0            4.4          3.0           1.3          0.2
# 1            4.7          3.2           1.6          0.2
# 2            6.1          2.6           5.6          1.4
# 3            6.4          3.1           5.5          1.8
# 4            5.8          4.0           1.2          0.2
# 5            5.0          3.5           1.6          0.6
# 6            5.0          2.0           3.5          1.0
# 7            4.9          3.1           1.5          0.1
# 8            6.3          2.8           5.1          1.5
# 9            5.6          2.8           4.9          2.0
# 10           4.9          2.5           4.5          1.7
# 11           6.4          2.8           5.6          2.2
# 12           6.2          2.8           4.8          1.8
# 13           5.0          3.3           1.4          0.2
# 14           7.2          3.2           6.0          1.8
# ...
